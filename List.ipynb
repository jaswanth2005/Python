# %% [raw]
#             DIFFERENCE BETWEEN DATA TYPE & DATA STRUCTURES
#
# ---> A data type defines the kind of value a variable can store      (like int, str, float, bool).
# ---> A data structure is a way of organizing and storing
#      multiple values efficiently.

# %% [markdown]
# List ==> []
# >List is Ordered and Mutable.
# >Duplication is allowed.
# >A list can have multiple data types ex:[int,bool,float ,string]
# >List is Growable.
# >A list can have a one more list in it -->"Nested List".

# %%
l=[]
l
# Out:
# []

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
l1=[10,30,50,23,56]

# %%
l2=[10.4,12.4,34.3,23.6,87.1]

# %%
l3=['one','three','hills']

# %%
l4=['Jaswanth',23,[50,54,12],[12,4,1],True,12.5]

# %%
l5=['Jaswanth',26,14.5,True,3+2j,]

# %%
len(l4)
# Out:
# 6

# %% [markdown]
# LIST INDEXING

# %%
print(l)
print(l1)
print(l2)
print(l3)
print(l4)
print(l5)
# Out:
# []
# [10, 30, 50, 23, 56]
# [10.4, 12.4, 34.3, 23.6, 87.1]
# ['one', 'three', 'hills']
# ['Jaswanth', 23, [50, 54, 12], [12, 4, 1], True, 12.5]
# ['Jaswanth', 26, 14.5, True, (3+2j)]

# %%
l2[0]
# Out:
# 10.4

# %%
l4[3]
# Out:
# [12, 4, 1]

# %%
l5[-1]
# Out:
# (3+2j)

# %% [markdown]
# LIST SLICING

# %%
l3[1:]
# Out:
# ['three', 'hills']

# %%
l4[-3:]
# Out:
# [[12, 4, 1], True, 12.5]

# %%
l2[:-2]
# Out:
# [10.4, 12.4, 34.3]

# %%
l4[:-1]
# Out:
# ['Jaswanth', 23, [50, 54, 12], [12, 4, 1], True]

# %% [markdown]
# INBUILT FUNCTIONS IN LIST

# %%
#Append -->adds one value to the List
l.append(5)
l
# Out:
# [5]

# %%
l2.append("Salaar")
l2
# Out:
# [10.4, 12.4, 34.3, 23.6, 87.1, 'Salaar']

# %%
# clear---> deletes the values in list.
l.clear()
l
# Out:
# []

# %%
l
# Out:
# []

# %%
# del ---> deletes the variable completely
del l

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
new =l3.copy()
print(new)
# Out:
# ['one', 'three', 'hills']

# %%
new
# Out:
# ['one', 'three', 'hills']

# %%
one=new
print(new)
# Out:
# ['one', 'three', 'hills']

# %%
#insert --> add the element at the given index
l2.insert(3,"Dune")
l2
# Out:
# [10.4, 12.4, 34.3, 'Dune', 23.6, 87.1, 'Salaar']

# %%
#remove --> remove the element given
l2.remove("Dune")
l2
# Out:
# [10.4, 12.4, 34.3, 23.6, 87.1]

# %%
# pop -->if no arg is passed, removes the-1 indexed element or if index given the deletes the indexed number.
l4.pop()
l4
# Out:
# ['Jaswanth', 23, [50, 54, 12], [12, 4, 1], True]

# %%
l4.pop()
l4
# Out:
# ['Jaswanth', 23, [50, 54, 12], [12, 4, 1]]

# %%
l4.pop(2)
l4
# Out:
# ['Jaswanth', 23, [12, 4, 1]]

# %%
# changes the Value
l4[0]=76
l4
# Out:
# [76, 23, [12, 4, 1]]

# %%
l5.extend(l3)
l5
# Out:
# ['Jaswanth', 26, 14.5, True, (3+2j), 'one', 'three', 'hills']

# %%
l2.reverse()
l2
# Out:
# [87.1, 23.6, 34.3, 12.4, 10.4]

# %%
l2.append(23.6)
l2
# Out:
# [87.1, 23.6, 34.3, 12.4, 10.4, 23.6]

# %%
l2.count(23.6)
# Out:
# 2

# %%
l2.index(10.4)
# Out:
# 4

# %%
#concatination of lists
l2.append(l5)
l2
# Out:
# [87.1,
#  23.6,
#  34.3,
#  12.4,
#  10.4,
#  23.6,
#  ['Jaswanth', 26, 14.5, True, (3+2j), 'one', 'three', 'hills']]

# %%
# List MemberShip
'Jaswanth' in l5
# Out:
# True

# %%
14.5 in l2
# Out:
# False

# %%
#Revere
l5.reverse()

# %%
l5
# Out:
# ['hills', 'three', 'one', (3+2j), True, 14.5, 26, 'Jaswanth']

# %%
l1.reverse()
l1
# Out:
# [56, 23, 50, 30, 10]

# %%
l1.sort()
l1
# Out:
# [10, 23, 30, 50, 56]

# %%
#loop through list
for i in l2:
    print(i)
# Out:
# 87.1
# 23.6
# 34.3
# 12.4
# 10.4
# 23.6
# ['hills', 'three', 'one', (3+2j), True, 14.5, 26, 'Jaswanth']
