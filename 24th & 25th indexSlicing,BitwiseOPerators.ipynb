# %%
spam=1
text="# This is not a comment"

print(spam)
print(text)
# Out:
# 1
# # This is not a comment

# %% [markdown]
#  3.1Using Python as a Calculator

# %%
a=5
b=2
add=a+b
sub=a-b
mul=a*b
div=a//b
div1=a/b
per=a%b
print("addition is{},{},{},{},{},{}".format(add,sub,mul,div,div1,per))
# Out:
# addition is7,3,10,2,2.5,1

# %% [markdown]
# Powers in Python

# %%
5**3
# Out:
# 125

# %% [markdown]
# Area of Square

# %%
height=50
width=25
width*height
# Out:
# 1250

# %% [markdown]
# Using _ to get the previous value

# %%
tax=12.5/100
price=100.50
price*tax
# Out:
# 213.5625

# %%
price +_
# Out:
# 314.0625

# %%
'doesnt'
# Out:
# 'doesnt'

# %%
"yes, they said"
# Out:
# 'yes, they said'

# %%
' "isn\'t,", they said'
# Out:
# ' "isn\'t,", they said'

# %%
print("""\
    Usage thingy [OPTIONS]
        -h                          Sisplay this usage message
        -H hostname                 Hostname to connect to
    """)
# Out:
#     Usage thingy [OPTIONS]
#         -h                          Sisplay this usage message
#         -H hostname                 Hostname to connect to

# %% [markdown]
# Concatination in Strings

# %%
3*'un'+'ium'
# Out:
# 'unununium'

# %% [markdown]
# String Indexing

# %%
word='Python'
word[0]
# Out:
# 'P'

# %% [markdown]
# BackWord Indexing

# %%
print(word[-1])
print(word[0:4])
print(word[2: ])
print(word[:4])
print(word[1:6:2])
print(word[::-1])
print(word[::1])
print(word[::-2])
# Out:
# n
# Pyth
# thon
# Pyth
# yhn
# nohtyP
# Python
# nhy

# %%
len(word)
# Out:
# 6

# %% [markdown]
# NUMBER SYSTEM

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
oct(0b0011)
# Out:
# '0o3'

# %%
hex(15)
# Out:
# '0xf'

# %% [markdown]
# BITWISE OPERATOR

# %%
print(~25) #complement
print(20 & 25) #and 
print(20 | 25) # or operator
print(20 ^ 25) # xor operator
print(21 >> 1) #Right Shift
print(21 << 2)  #Left Shift
# Out:
# -26
# 16
# 29
# 13
# 10
# 84

# %%
#Swapping two numbers using XOR operator
a=5
b=7

a=a^b
b=a^b
a=a^b
print("the numbers after swapping is a=",a,"b=",b)
# Out:
# the numbers after swapping is a= 7 b= 5
