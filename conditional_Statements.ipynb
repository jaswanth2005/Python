# %%
#1. input() function  in python used to get User Input

# %%
#2. using int(input("enter a Integer") we accept an integer as input from the user using input(), because by default input() reads "String"
sample=int(input("enter a Integer: "))
# Out:
# enter a Integer:  25

# %%
sample2=float(input("enter a Float Number: "))
# Out:
# enter a Float Number:  2.5

# %%
#3.
a, b, c = map(int, input("Enter numbers: ").split())
print(a, b, c)
# Out:
# Enter numbers:  23 54 65
# 23 54 65

# %%
#check if given number is postive /negative / zero
num1=int(input("enter a Value"))
if num1 >0:
    print("positive")
elif num1< 0:
    print("Negative")
else:
    print("Zero")
# Out:
# enter a Value 45
# positive

# %%
nums=[int(x) for x in input("enter the numbers").split()]
print(nums)
# Out:
# enter the numbers 23 233 24 35 4
# [23, 233, 24, 35, 4]

# %%
str1=input("enter a string")
print(str1.upper())
# Out:
# enter a string jaswanth
# JASWANTH

# %%
str2=input("enter a string")
vowels="aeiou"
count=sum(1 for char in str2 if char.lower() in vowels)
print("number of vowels in Str2: ",count)
# Out:
# enter a string Jaswanth Reddy
# number of vowels in Str2:  3

# %%
num2=int(input("enter a number"))
if num2 % 2==0:
    print("even")
else:
    print("odd")
# Out:
# enter a number 45
# odd

# %%
str3=input("enter a string")
if str3 == str3[::-1]:
    print("palindrome")
else:
    print("not a palindrome")
# Out:
# enter a string madam
# palindrome

# %%
num3=int(input("enter a string"))
print("square: ",num3*num3)
# Out:
# enter a string 4
# square:  16

# %%
num4=int(input("enter a number: "))
if num4 %3 == 0:
    print("divisibe by 3")
else:
    print("not divisible by 3")
# Out:
# enter a number:  9
# divisibe by 3

# %%
num5=int(input("enter a number: "))
if num5 %3 == 0 and num5 % 7 == 0 :
    print("divisibe by 3 and 7")
else:
    print("not divisible by 3 and 7")
# Out:
# enter a number:  21
# divisibe by 3 and 7

# %%
values = input("Enter comma-separated values: ").split(',')
# Out:
# Enter comma-separated values:  22,3,2,342,33,21,4

# %%
sam1=int(input('enter a number'))
sam2=int(input('enter a number'))
print("product: ",sam1*sam2)
# Out:
# enter a number 32
# enter a number 43
# product:  1376

# %%
prim=int(input("enter a number"))
if prim > 1:
    for i in range(2,prim):
        if prim % i==0:
            print("not a prime number")
            break
    else:
        print("prime number")
else:
        print("not a prime number")
# Out:
# enter a number 3
# prime number

# %%
  user_input = input("Enter True or False: ").lower() == "true"
# Out:
# Enter True or False:  true

# %%
str4=input("enter a string")
print("reveseed string:",str4[::-1])
# Out:
# enter a string Jassu
# reveseed string: ussaJ

# %%
name=input("enter a Name")
age=int(input("enter your age"))
print(f"Hi,{name}. I am {age} years old")
# Out:
# enter a Name jaswanth
# enter your age 21
# Hi,jaswanth. I am 21 years old

# %%
nums=int(input("enter a number"))
fact=1
for i in range(1,nums+1):
    fact *=i
print(f"factorial of {nums} is: ",fact)
# Out:
# enter a number 5
# factorial of 5 is:  120

# %%
user_input=input("enter a string").strip()
if not user_input:
    print("input cannot be empty")
else:
    print(f"you entered:{user_input}")
# Out:
# enter a string
# input cannot be empty

# %%
import math
num6=int(input("enter a number"))
if math.sqrt(num6) **2==num6:
    print(f"{num6} is a perfect square")
else:
    print(f"{num6} is not a perfect square")
# Out:
# enter a number 4
# 4 is a perfect square

# %%
# leap Year
year=int(input("enter a string"))
if(year % 4 ==0 and year % 100!=0) or (year %400 ==0):
    print(f"{year} is a leap Year")
else:
    print("not a leap year")
# Out:
# enter a string 2023
# not a leap year

# %%
user_input1=input("enter a string").strip()
new=user_input1.replace(" ","")
print(new)
# Out:
# enter a string Jaswanth Reddy
# JaswanthReddy

# %%
try:
    num=int(input("enter a input: "))
except ValueError:
    print("Invalide Input! PLease  enter a value Integer.")
# Out:
# enter a input:  2345

# %%
text=input("enter a string")
char=input("Enter a character to count")
print(f"Occurences of {char}:{text.count(char)}")
# Out:
# enter a string y
# Enter a character to count y
# Occurences of y:1

# %%
user_input2=input("enter a string").lower()
print(user_input2)
# Out:
# enter a string JaswantH
# jaswanth

# %%
num7=int(input("enter a  number"))
if num7 % 10 ==0:
    print(f"{num7} is divisible by 10")
else:
    print("not divisible by 10")
# Out:
# enter a  number 10
# 10 is divisible by 10

# %%
user_input3=input("enter a string")
if user_input3.isalpha():
    print("only alphabets")
else:
    print("contains a non alphabetical character")
# Out:
# enter a string Jaswanth
# only alphabets

# %%
text1=input("enter a sentence")
print( f"\nnumber of words in {text1} is: ",len(text1.split()))
# Out:
# enter a sentence Jaswanth
# number of words in Jaswanth is:  1

# %%
from datetime import datetime
date_str=input("enter a date")
date=datetime.strptime(date_str,"%Y-%m-%d")
print("entered date:",date)
# Out:
# enter a date 2000-10-30
# entered date: 2000-10-30 00:00:00

# %%
num8=int(input("enter a number"))
if(num8 % 3 == 0 and num % 5 == 0):
    print(f"{num8} is divisible by both 3 and 5")
else:
    print("not divisible by 3 and 5")
# Out:
# enter a number 15
# 15 is divisible by both 3 and 5

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
a,b=b,a
print(f"swapped numbers: a={a},b={b}")
# Out:
# enter a number 3
# enter a number 7
# swapped numbers: a=7,b=3

# %%
inp=input("enter a string")
n=inp.replace(" ","")
print(n)
# Out:
# enter a string Jaswa nth
# Jaswanth

# %%
import math
num9=int(input("enter a number"))
print("cube:",num9**3)
# Out:
# enter a number 9
# cube: 729

# %%
import re
text_2=input("enter a string")
numf=re.findall(r"\d+",text_2)
print("Extracted numbers.",numf)
# Out:
# enter a string I'm 16 years old
# Extracted numbers. ['16']

# %%
numbers=list(map(int,input("enter a numbers").split()))
print("Maximum Number: ",max(numbers))
# Out:
# enter a numbers 20 30 40 03 450
# Maximum Number:  450

# %%
while True:
    try:
        num=int(input("enter a number"))
        break
    except ValueError:
        print("Invalid Input!,Please enter a number")
# Out:
# enter a number 1244J22
# Invalid Input!,Please enter a number
# enter a number 12345

# %%
userInput=input("enter a string")
if any(char.isdigit() for char in userInput):
    print("contains digits")
else:
    print("no digits")
# Out:
# enter a string I'm 21 years old
# contains digits

# %%
user_input4=input('enter a string')
if user_input4.isspace():
    print("contains white space")
else:
    print("contains no white space character")
# Out:
# enter a string Jaswanth     reddy
# contains no white space character

# %%
text = input("Enter a string: ") 
digit_sum = sum(int(digit) for digit in text if digit.isdigit()) 
print("Sum of digits:", digit_sum)
# Out:
# Enter a string:  234
# Sum of digits: 9

# %%
num9=int(input("enter a value"))
print("Absolute Value",abs(num9))
# Out:
# enter a value 89
# Absolute Value 89

# %%
nums1=input("Enter a number")
if any(char.isupper() for char in nums1):
    print("upper case is present")
else:
    print("no upperCase is present")
# Out:
# Enter a number Jassu
# upper case is present

# %% [markdown]
# celsius = float(input("Enter temperature in Celsius: "))
# fahrenheit = (celsius * 9/5) + 32
# print(f"Temperature in Fahrenheit: {fahrenheit}")

# %%
nums3=list(map(int,input("enter the Values").split()))
print("Average: ",sum(nums3)/len(nums3))
# Out:
# enter the Values 12 2 12 32 12 3
# Average:  12.166666666666666

# %%
text = input("Enter a sentence: ") 
words = text.split() 
longest_word = max(words, key=len) 
print("Longest word:", longest_word)
# Out:
# Enter a sentence:  my name is Jaswanth Reddy
# Longest word: Jaswanth
